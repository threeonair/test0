# %% [markdown]
# # Test - Function and Class

# %%
print('This is a test')
# Out:
# This is a test

# %%
1+2
# Out:
# 3

# %%
def testfunc (var1,var2):
  varsum = var1 + var2
  return varsum

# %%
one = testfunc(2,3)
print(one)
# Out:
# 5

# %%
class Cat:
  def __init__(self,color,age):
    self.color=color
    self.age=age
  def cat_sound():
    self.sound='mew'

cat1 = Cat("black",3)
print (cat1.color)
# Out:
# black
