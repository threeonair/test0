# %%
def f(a):
  print(a)

# %%
f('0')
# Out:
# 0

# %%
# Lets try something new

# %%
y = int(2.3)
print(y)
# Out:
# 2

# %%
fruits = ('apple','banana','cherry')

# %%
fruits
# Out:
# ('apple', 'banana', 'cherry')

# %%
for fruit in fruits:
  print(fruit)
# Out:
# apple
# banana
# cherry

# %%
this_dict = {
    'make' : 'toyota',
    'model' : 'corlla',
    'year' : '2012'
}

# %%
this_dict
# Out:
# {'make': 'toyota', 'model': 'corlla', 'year': '2012'}

# %%
this_dict['make']
# Out:
# 'toyota'

# %%
this_dict['owner']='Niloy'

# %%
this_dict
# Out:
# {'make': 'toyota', 'model': 'corlla', 'year': '2012', 'owner': 'Niloy'}

# %%
fruits = ['Apple','Banana','Cherry','Orange','Guava']

for fruit in fruits:
  if fruit == 'Orange':
   break
  print(fruit)
# Out:
# Apple
# Banana
# Cherry
