# %% [markdown]
# #LOOP

# %%
fruits = {'apple','banana', 'orange}
for fruit in fruits:
  print (fruit)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1164866721.py in <cell line: 0>()
# ----> 1 fruits = {apple,banana, orange}
#       2 for fruit in fruits:
#       3   print (fruit)
#
# NameError: name 'apple' is not defined
